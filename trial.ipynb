# %%
import torch
import os

# %%
import pickle

# %%
directory = './Dataset/data_tf/'
file_name = 'ind.citeseer.tx'
file_path = os.path.join(directory, file_name)
with open(file_path, 'rb') as f:
    data = pickle.load(f)
    print(f"File: {file_name}")
    if hasattr(data, 'shape'):
        print(f"Shape: {data.shape}")
    else:
        print("The loaded data does not have a 'shape' attribute.")
# Out:
# File: ind.citeseer.tx
# Shape: (832, 3703)

# %%
directory = './Dataset/data_tf/'
file_name = 'ind.citeseer.allx'
file_path = os.path.join(directory, file_name)
with open(file_path, 'rb') as f:
    data = pickle.load(f)
    print(f"File: {file_name}")
    if hasattr(data, 'shape'):
        print(f"Shape: {data.shape}")
    else:
        print("The loaded data does not have a 'shape' attribute.")
# Out:
# File: ind.citeseer.allx
# Shape: (2495, 3703)

# %%
directory = './Dataset/data_tf/'
file_name = 'ind.citeseer.x'
file_path = os.path.join(directory, file_name)
with open(file_path, 'rb') as f:
    data = pickle.load(f)
    print(f"File: {file_name}")
    if hasattr(data, 'shape'):
        print(f"Shape: {data.shape}")
    else:
        print("The loaded data does not have a 'shape' attribute.")
# Out:
# File: ind.citeseer.x
# Shape: (1663, 3703)
